# %% [markdown]
# # My Final Grade Claim
# ## CSE 380 Discrete Mathematics II
# ### Winter 2021

# %% [markdown]
# ![Grade Claim Chart.jpg](data:image/jpeg;base64,...)
#
# I did participate in the discussions over the last 4 weeks, and I scored at least a 3 each time.

# %% [markdown]
# ## My Links to other Notebooks

# %% [markdown]
# [Ponder & Prove (Pigeonhole Principle)](
# https://github.com/G-Dubs/cse380-notebooks/blob/master/12_2_Ponder_and_Prove_The_Pigeonhole_Principle.ipynb)

# %% [markdown]
# [11-1 (Word Graphs)](https://colab.research.google.com/github/G-Dubs/cse380-notebooks/blob/master/11_1_About_Paths_in_Word_Graphs.ipynb#scrollTo=o71SYAt1leka)

# %% [markdown]
# [13-2 Ponder & Prove](https://github.com/G-Dubs/cse380-notebooks/blob/master/13_2_Ponder_and_Prove_Many_Things.ipynb)

# %% [markdown]
# [12-3 About Deterministic Finite Automata](https://github.com/G-Dubs/cse380-notebooks/blob/master/12_3_About_Deterministic_Finite_Automata.ipynb)
